# %% [markdown]
# # Workflow 1 example code for RTX system
# # Modules 1 and 2
# ## Eric Deutsch, Institute for Systems Biology
#
# The code in this notebook remotely executes this code module in the RTX server:
# https://github.com/RTXteam/RTX/blob/master/code/reasoningtool/QuestionAnswering/SMEDrugRepurposingFisher.py

# %%
#### Import some needed modules
import requests
import json
import sys

# %%
#### Set the base URL for the reasoner and its endpoint
API_BASE_URL = 'https://rtx.ncats.io/api/rtx/v1'
url_str = API_BASE_URL + "/query"

# %%
#### Create a dict of the request, specifying the query type and its parameters
request = { "query_type_id": "Q55", "terms": { "disease": "DOID:9352" } }

# %%
#### Send the request to RTX and check the status
response_content = requests.post(url_str, json=request, headers={'accept': 'application/json'})
status_code = response_content.status_code
assert status_code == 200

# %%
#### Unpack the response content into a dict
response_dict = response_content.json()

# %%
#### Display the summary table of the results
if "table_column_names" in response_dict:
  print("\t".join(response_dict["table_column_names"]))
  for result in response_dict["result_list"]:
    print("\t".join(result["row_data"]))
    
#### NOTE: Some rows below appear as duplicates in this summary table but they correspond to different paths in the KG.
# Out:
# disease name	disease ID	drug name	drug ID	path weight	drug disease google distance	ML probability drug treats disease
# type 2 diabetes mellitus	DOID:9352	sodium acetate	CHEMBL.COMPOUND:CHEMBL1354	1998.005415	nan	0.600278
# type 2 diabetes mellitus	DOID:9352	sodium acetate	CHEMBL.COMPOUND:CHEMBL1354	1998.005415	nan	0.600278
# type 2 diabetes mellitus	DOID:9352	oxcarbazepine	CHEMBL.COMPOUND:CHEMBL1068	1998.005415	0.872659	0.661540
# type 2 diabetes mellitus	DOID:9352	oxcarbazepine	CHEMBL.COMPOUND:CHEMBL1068	1998.005415	0.872659	0.661540
# type 2 diabetes mellitus	DOID:9352	mephenytoin	CHEMBL.COMPOUND:CHEMBL861	1998.005415	nan	0.496979
# type 2 diabetes mellitus	DOID:9352	mephenytoin	CHEMBL.COMPOUND:CHEMBL861	1998.005415	nan	0.496979
# type 2 diabetes mellitus	DOID:9352	riluzole	CHEMBL.COMPOUND:CHEMBL744	1998.005415	nan	0.554316
# type 2 diabetes mellitus	DOID:9352	riluzole	CHEMBL.COMPOUND:CHEMBL744	1998.005415	nan	0.554316
# type 2 diabetes mellitus	DOID:9352	carbamazepine	CHEMBL.COMPOUND:CHEMBL108	1998.005415	0.896211	0.788517
# type 2 diabetes mellitus	DOID:9352	carbamazepine	CHEMBL.COMPOUND:CHEMBL108	1998.005415	0.896211	0.788517
# type 2 diabetes mellitus	DOID:9352	ethotoin	CHEMBL.COMPOUND:CHEMBL1095	1998.005415	nan	0.628893
# type 2 diabetes mellitus	DOID:9352	ethotoin	CHEMBL.COMPOUND:CHEMBL1095	1998.005415	nan	0.628893
# type 2 diabetes mellitus	DOID:9352	phenazopyridine	CHEMBL.COMPOUND:CHEMBL1242	1998.005415	nan	0.164713
# type 2 diabetes mellitus	DOID:9352	phenazopyridine	CHEMBL.COMPOUND:CHEMBL1242	1998.005415	nan	0.164713
# type 2 diabetes mellitus	DOID:9352	lacosamide	CHEMBL.COMPOUND:CHEMBL58323	1998.005415	nan	0.555937
# type 2 diabetes mellitus	DOID:9352	lacosamide	CHEMBL.COMPOUND:CHEMBL58323	1998.005415	nan	0.555937
# type 2 diabetes mellitus	DOID:9352	eslicarbazepine	CHEMBL.COMPOUND:CHEMBL315985	1998.005415	nan	0.764038
# type 2 diabetes mellitus	DOID:9352	eslicarbazepine	CHEMBL.COMPOUND:CHEMBL315985	1998.005415	nan	0.764038
# type 2 diabetes mellitus	DOID:9352	phenacemide	CHEMBL.COMPOUND:CHEMBL918	1998.005415	nan	0.802114
# type 2 diabetes mellitus	DOID:9352	phenacemide	CHEMBL.COMPOUND:CHEMBL918	1998.005415	nan	0.802114
# type 2 diabetes mellitus	DOID:9352	rufinamide	CHEMBL.COMPOUND:CHEMBL1201754	1998.005415	nan	0.704489
# type 2 diabetes mellitus	DOID:9352	rufinamide	CHEMBL.COMPOUND:CHEMBL1201754	1998.005415	nan	0.704489
# type 2 diabetes mellitus	DOID:9352	tetracaine	CHEMBL.COMPOUND:CHEMBL698	1998.005415	nan	0.349983
# type 2 diabetes mellitus	DOID:9352	tetracaine	CHEMBL.COMPOUND:CHEMBL698	1998.005415	nan	0.349983
# type 2 diabetes mellitus	DOID:9352	zonisamide	CHEMBL.COMPOUND:CHEMBL750	1998.005415	0.846468	0.600636
# type 2 diabetes mellitus	DOID:9352	zonisamide	CHEMBL.COMPOUND:CHEMBL750	1998.005415	0.846468	0.600636
# type 2 diabetes mellitus	DOID:9352	lamotrigine	CHEMBL.COMPOUND:CHEMBL741	1998.005415	0.949483	0.423309
# type 2 diabetes mellitus	DOID:9352	lamotrigine	CHEMBL.COMPOUND:CHEMBL741	1998.005415	0.949483	0.423309
# type 2 diabetes mellitus	DOID:9352	prilocaine	CHEMBL.COMPOUND:CHEMBL1194	1998.005415	nan	0.910000
# type 2 diabetes mellitus	DOID:9352	prilocaine	CHEMBL.COMPOUND:CHEMBL1194	1998.005415	nan	0.910000
# type 2 diabetes mellitus	DOID:9352	phenytoin	CHEMBL.COMPOUND:CHEMBL16	1998.005415	0.902583	0.797283
# type 2 diabetes mellitus	DOID:9352	phenytoin	CHEMBL.COMPOUND:CHEMBL16	1998.005415	0.902583	0.797283
# type 2 diabetes mellitus	DOID:9352	lidocaine	CHEMBL.COMPOUND:CHEMBL79	1998.005415	0.898003	0.783724
# type 2 diabetes mellitus	DOID:9352	lidocaine	CHEMBL.COMPOUND:CHEMBL79	1998.005415	0.898003	0.783724
# type 2 diabetes mellitus	DOID:9352	primidone	CHEMBL.COMPOUND:CHEMBL856	1998.005415	nan	0.888345
# type 2 diabetes mellitus	DOID:9352	primidone	CHEMBL.COMPOUND:CHEMBL856	1998.005415	nan	0.888345
# type 2 diabetes mellitus	DOID:9352	topiramate	CHEMBL.COMPOUND:CHEMBL220492	1998.005415	0.693590	0.706654
# type 2 diabetes mellitus	DOID:9352	topiramate	CHEMBL.COMPOUND:CHEMBL220492	1998.005415	0.693590	0.706654
# type 2 diabetes mellitus	DOID:9352	sodium glycerophosphate	CHEMBL.COMPOUND:CHEMBL3039567	1998.005415	0.748916	0.688158
# type 2 diabetes mellitus	DOID:9352	sodium glycerophosphate	CHEMBL.COMPOUND:CHEMBL3039567	1998.005415	0.748916	0.688158
# type 2 diabetes mellitus	DOID:9352	flurothyl	CHEMBL.COMPOUND:CHEMBL477874	1998.005415	nan	0.817106
# type 2 diabetes mellitus	DOID:9352	flurothyl	CHEMBL.COMPOUND:CHEMBL477874	1998.005415	nan	0.817106
# type 2 diabetes mellitus	DOID:9352	ropivacaine	CHEMBL.COMPOUND:CHEMBL1077896	1998.005415	0.856324	0.592597
# type 2 diabetes mellitus	DOID:9352	ropivacaine	CHEMBL.COMPOUND:CHEMBL1077896	1998.005415	0.856324	0.592597
# type 2 diabetes mellitus	DOID:9352	procainamide	CHEMBL.COMPOUND:CHEMBL640	1998.005415	0.975946	0.593972
# type 2 diabetes mellitus	DOID:9352	procainamide	CHEMBL.COMPOUND:CHEMBL640	1998.005415	0.975946	0.593972
# type 2 diabetes mellitus	DOID:9352	mepivacaine	CHEMBL.COMPOUND:CHEMBL1087	1998.005415	nan	0.750173
# type 2 diabetes mellitus	DOID:9352	mepivacaine	CHEMBL.COMPOUND:CHEMBL1087	1998.005415	nan	0.750173
# type 2 diabetes mellitus	DOID:9352	tocainide	CHEMBL.COMPOUND:CHEMBL1762	1998.005415	nan	0.706359
# type 2 diabetes mellitus	DOID:9352	tocainide	CHEMBL.COMPOUND:CHEMBL1762	1998.005415	nan	0.706359

# %%
#### Or dump the whole detailed JSON response_content data structure
print(json.dumps(response_dict, indent=4, sort_keys=True))
# Out:
# {
#     "context": "https://raw.githubusercontent.com/biolink/biolink-model/master/context.jsonld",
#     "datetime": "2018-08-14 22:02:42",
#     "id": "http://rtx.ncats.io/api/rtx/v1/response/322",
#     "message": "50 results found",
#     "original_question_text": "What are some potential treatments for type 2 diabetes mellitus based on knowledge of related rare conditions",
#     "query_type_id": "Q55",
#     "reasoner_id": "RTX",
#     "response_code": "OK",
#     "restated_question_text": "What are some potential treatments for type 2 diabetes mellitus based on knowledge of related rare conditions",
#     "result_list": [
#         {
#             "confidence": 0.6002781567596541,
#             "essence": "sodium acetate",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6436",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011466",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011466",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1354",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL1354",
#                         "target_id": "UniProtKB:Q01118",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "Absence or underdevelopment of the gallbladder.",
#                         "id": "HP:0011466",
#                         "name": "Aplasia/Hypoplasia of the gallbladder",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011466"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1354",
#                         "name": "sodium acetate",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1354"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "sodium acetate",
#                 "CHEMBL.COMPOUND:CHEMBL1354",
#                 "1998.005415",
#                 "nan",
#                 "0.600278"
#             ],
#             "text": "The drug sodium acetate is predicted to treat type 2 diabetes mellitus."
#         },
#         {
#             "confidence": 0.6002781567596541,
#             "essence": "sodium acetate",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6437",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1354",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL1354",
#                         "target_id": "UniProtKB:Q01118",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A developmental defect of the pericardium with congenital onset.",
#                         "id": "HP:0011628",
#                         "name": "Congenital defect of the pericardium",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011628"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1354",
#                         "name": "sodium acetate",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1354"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "sodium acetate",
#                 "CHEMBL.COMPOUND:CHEMBL1354",
#                 "1998.005415",
#                 "nan",
#                 "0.600278"
#             ],
#             "text": "The drug sodium acetate is predicted to treat type 2 diabetes mellitus."
#         },
#         {
#             "confidence": 0.6615401504471925,
#             "essence": "oxcarbazepine",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6438",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011466",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1068",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011466",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "A dibenzoazepine derivative, having a carbamoyl group at the ring nitrogen, substituted with an oxo group at C-4 of the azepeine ring which is also hydrogenated at C-4 and C-5. It is a anticholinergic anticonvulsant and mood stabilizing drug, used primarily in the treatment of epilepsy.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1068",
#                         "name": "oxcarbazepine",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1068"
#                     },
#                     {
#                         "description": "Absence or underdevelopment of the gallbladder.",
#                         "id": "HP:0011466",
#                         "name": "Aplasia/Hypoplasia of the gallbladder",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011466"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "oxcarbazepine",
#                 "CHEMBL.COMPOUND:CHEMBL1068",
#                 "1998.005415",
#                 "0.872659",
#                 "0.661540"
#             ],
#             "text": "The drug oxcarbazepine is predicted to treat type 2 diabetes mellitus."
#         },
#         {
#             "confidence": 0.6615401504471925,
#             "essence": "oxcarbazepine",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6439",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL1068",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A developmental defect of the pericardium with congenital onset.",
#                         "id": "HP:0011628",
#                         "name": "Congenital defect of the pericardium",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011628"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "A dibenzoazepine derivative, having a carbamoyl group at the ring nitrogen, substituted with an oxo group at C-4 of the azepeine ring which is also hydrogenated at C-4 and C-5. It is a anticholinergic anticonvulsant and mood stabilizing drug, used primarily in the treatment of epilepsy.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1068",
#                         "name": "oxcarbazepine",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1068"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "oxcarbazepine",
#                 "CHEMBL.COMPOUND:CHEMBL1068",
#                 "1998.005415",
#                 "0.872659",
#                 "0.661540"
#             ],
#             "text": "The drug oxcarbazepine is predicted to treat type 2 diabetes mellitus."
#         },
#         {
#             "confidence": 0.4969792061988593,
#             "essence": "mephenytoin",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6440",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011466",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL861",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011466",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "None",
#                         "id": "CHEMBL.COMPOUND:CHEMBL861",
#                         "name": "mephenytoin",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL861"
#                     },
#                     {
#                         "description": "Absence or underdevelopment of the gallbladder.",
#                         "id": "HP:0011466",
#                         "name": "Aplasia/Hypoplasia of the gallbladder",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011466"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "mephenytoin",
#                 "CHEMBL.COMPOUND:CHEMBL861",
#                 "1998.005415",
#                 "nan",
#                 "0.496979"
#             ],
#             "text": "The drug mephenytoin is predicted to treat type 2 diabetes mellitus."
#         },
#         {
#             "confidence": 0.4969792061988593,
#             "essence": "mephenytoin",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6441",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "CHEMBL.COMPOUND:CHEMBL861",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A developmental defect of the pericardium with congenital onset.",
#                         "id": "HP:0011628",
#                         "name": "Congenital defect of the pericardium",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011628"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
# ...
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A monocarboxylic acid amide in which 2,6-dimethylphenylaniline and isobutyric acid have combined to form the amide bond; used as a local anaesthetic.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1762",
#                         "name": "tocainide",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1762"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "Absence or underdevelopment of the gallbladder.",
#                         "id": "HP:0011466",
#                         "name": "Aplasia/Hypoplasia of the gallbladder",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011466"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "tocainide",
#                 "CHEMBL.COMPOUND:CHEMBL1762",
#                 "1998.005415",
#                 "nan",
#                 "0.706359"
#             ],
#             "text": "The drug tocainide is predicted to treat type 2 diabetes mellitus."
#         },
#         {
#             "confidence": 0.7063593264303701,
#             "essence": "tocainide",
#             "id": "http://rtx.ncats.io/api/rtx/v1/result/6485",
#             "reasoner_id": "RTX",
#             "result_graph": {
#                 "edge_list": [
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "OMIM:600001",
#                         "type": "gene_mutations_contribute_to"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q92908",
#                         "source_id": "UniProtKB:Q92908",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/OMIM_600001",
#                         "source_id": "OMIM:600001",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://purl.obolibrary.org/obo/DOID_9352",
#                         "source_id": "DOID:9352",
#                         "target_id": "HP:0011628",
#                         "type": "has_phenotype"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1762",
#                         "source_id": "CHEMBL.COMPOUND:CHEMBL1762",
#                         "target_id": "UniProtKB:Q01118",
#                         "type": "physically_interacts_with"
#                     },
#                     {
#                         "is_defined_by": "RTX",
#                         "provided_by": "http://identifiers.org/uniprot/Q01118",
#                         "source_id": "UniProtKB:Q01118",
#                         "target_id": "REACT:R-HSA-5683826",
#                         "type": "participates_in"
#                     }
#                 ],
#                 "node_list": [
#                     {
#                         "description": "This gene is a member of a small family of zinc finger transcription factors that play an important role in the regulation of cellular differentiation and organogenesis during vertebrate development. This gene is expressed during early embryogenesis and localizes to endo- and mesodermally derived cells during later embryogenesis and thereby plays an important role in gut, lung, and heart development. Mutations in this gene are associated with several congenital defects. [provided by RefSeq, Mar 2012].",
#                         "id": "UniProtKB:Q92908",
#                         "name": "GATA binding protein 6",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q92908"
#                     },
#                     {
#                         "description": "A developmental defect of the pericardium with congenital onset.",
#                         "id": "HP:0011628",
#                         "name": "Congenital defect of the pericardium",
#                         "type": "phenotypic_feature",
#                         "uri": "http://purl.obolibrary.org/obo/HP_0011628"
#                     },
#                     {
#                         "description": "A monocarboxylic acid amide in which 2,6-dimethylphenylaniline and isobutyric acid have combined to form the amide bond; used as a local anaesthetic.",
#                         "id": "CHEMBL.COMPOUND:CHEMBL1762",
#                         "name": "tocainide",
#                         "type": "chemical_substance",
#                         "uri": "https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1762"
#                     },
#                     {
#                         "description": "A diabetes mellitus that involves high blood glucose resulting from cells fail to use insulin properly.",
#                         "id": "DOID:9352",
#                         "name": "type 2 diabetes mellitus",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/DOID_9352"
#                     },
#                     {
#                         "description": "None",
#                         "id": "OMIM:600001",
#                         "name": "HEART DEFECTS, CONGENITAL, AND OTHER CONGENITAL ANOMALIES; HDCA",
#                         "type": "disease",
#                         "uri": "http://purl.obolibrary.org/obo/OMIM_600001"
#                     },
#                     {
#                         "description": "The alveolar region of the lung creates an extensive epithelial surface that mediates the transfer of oxygen and carbon dioxide required for respiration after birth. Type I epithelial cells form the alveolar surface and mediate gaseous exchange. Type II epithelial cells secrete pulmonary surfactant, a lipoprotein complex that forms a thin interfacial film, lowering surface tension at the air-liquid interface in alveoli and maintaining the structural integrity of alveoli, preventing their collapse at low volumes (Agassandian & Mallampalli 2013). Surfactant production is increased prior to birth, in preparation for air breathing at birth (Hallman 2013). Pre-term infants, where type II epithelial cells are not fully differentiated yet, can produce insufficient surfactant and result in respiratory distress syndrome. Surfactant is composed primarily of phospholipids enriched in phosphatidylcholine (PC) and phosphatidylglycerol (PG) (Agassandian & Mallampalli 2013) and the pulmonary collectins, termed surfactant proteins A, B, C and D (SFTPA-D). They influence surfactant homeostasis, contributing to the physical structures of lipids in the alveoli and to the regulation of surfactant function and metabolism. They are directly secreted from alveolar type II cells into the airway to function as part of the surfactant. SFTPA and D are large, hydrophilic proteins while SFTPB and C are small, very hydrophobic proteins (Johansson et al. 1994). In addition to their surfactant functions, SFTPA and D play important roles in innate host defense by binding and clearing invading microbes from the lung (Kingma & Whitsett 2006). Nuclear regulation, transport, metabolism, reutilisation and degradation of surfactant are described here (Ikegami 2006, Boggaram 2009, Whitsett et al. 2010). Mutations in genes involved in these processes can result in respiratory distress syndrome, lung proteinosis, interstitial lung diseases and chronic lung diseases (Perez-Gil & Weaver 2010, Whitsett et al. 2010, Akella & Deshpande 2013, Jo 2014).",
#                         "id": "REACT:R-HSA-5683826",
#                         "name": "Surfactant metabolism",
#                         "type": "pathway",
#                         "uri": "https://reactome.org/content/detail/R-HSA-5683826"
#                     },
#                     {
#                         "description": "This gene encodes one of the many voltage-gated sodium channel proteins. For proper functioning of neurons and muscles during action potentials, voltage-gated sodium channels direct sodium ion diffusion for membrane depolarization. This sodium channel protein has some atypical characteristics; the similarity between the human and mouse proteins is lower compared to other orthologous sodium channel pairs. Also, the S4 segments, which sense voltage changes, have fewer positive charged residues that in other sodium channels; domain 4 has fewer arginine and lysine residues compared to other sodium channel proteins. Several alternatively spliced transcript variants exist, but the full-length natures of all of them remain unknown. [provided by RefSeq, Dec 2011].",
#                         "id": "UniProtKB:Q01118",
#                         "name": "sodium voltage-gated channel alpha subunit 7",
#                         "type": "protein",
#                         "uri": "http://identifiers.org/uniprot/Q01118"
#                     }
#                 ]
#             },
#             "result_type": "individual query answer",
#             "row_data": [
#                 "type 2 diabetes mellitus",
#                 "DOID:9352",
#                 "tocainide",
#                 "CHEMBL.COMPOUND:CHEMBL1762",
#                 "1998.005415",
#                 "nan",
#                 "0.706359"
#             ],
#             "text": "The drug tocainide is predicted to treat type 2 diabetes mellitus."
#         }
#     ],
#     "schema_version": "0.8.0",
#     "table_column_names": [
#         "disease name",
#         "disease ID",
#         "drug name",
#         "drug ID",
#         "path weight",
#         "drug disease google distance",
#         "ML probability drug treats disease"
#     ],
#     "terms": {
#         "disease": "DOID:9352"
#     },
#     "tool_version": "RTX 0.5.4",
#     "type": "medical_translator_query_response"
# }
